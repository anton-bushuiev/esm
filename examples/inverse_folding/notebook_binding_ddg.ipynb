# %% [markdown]
# This notebook reproduces the test results of ESM-IF in the [PPIformer paper](https://arxiv.org/pdf/2310.18515.pdf).

# %%
# !pip install git+https://github.com/anton-bushuiev/mutils.git
# Out:
# Collecting git+https://github.com/anton-bushuiev/mutils.git
#   Cloning https://github.com/anton-bushuiev/mutils.git to /private/var/folders/yw/q5k8tqgn3tq8_y9lbqhwm_8m0000gn/T/pip-req-build-d67l1p26
#   Running command git clone --filter=blob:none --quiet https://github.com/anton-bushuiev/mutils.git /private/var/folders/yw/q5k8tqgn3tq8_y9lbqhwm_8m0000gn/T/pip-req-build-d67l1p26
#   Resolved https://github.com/anton-bushuiev/mutils.git to commit e0d0d7dfcfe00f03a516d720eb0329226769da85
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: anyio==3.6.2 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (3.6.2)
# Requirement already satisfied: appdirs==1.4.4 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.4.4)
# Requirement already satisfied: appnope==0.1.3 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.1.3)
# Requirement already satisfied: argon2-cffi==21.3.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (21.3.0)
# Requirement already satisfied: argon2-cffi-bindings==21.2.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (21.2.0)
# Requirement already satisfied: arrow==1.2.3 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.2.3)
# Requirement already satisfied: asttokens==2.2.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (2.2.1)
# Requirement already satisfied: attrs==23.1.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (23.1.0)
# Requirement already satisfied: backcall==0.2.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.2.0)
# Requirement already satisfied: backports.functools-lru-cache==1.6.4 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.6.4)
# Requirement already satisfied: beautifulsoup4==4.12.2 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (4.12.2)
# Requirement already satisfied: biopandas==0.5.0.dev0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.5.0.dev0)
# Requirement already satisfied: biopython==1.81 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.81)
# Requirement already satisfied: bioservices==1.11.2 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.11.2)
# Requirement already satisfied: bleach==6.0.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (6.0.0)
# Requirement already satisfied: cattrs==22.2.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (22.2.0)
# Requirement already satisfied: certifi==2023.5.7 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (2023.5.7)
# Requirement already satisfied: cffi==1.15.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.15.1)
# Requirement already satisfied: charset-normalizer==3.1.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (3.1.0)
# Requirement already satisfied: click==8.1.3 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (8.1.3)
# Requirement already satisfied: colorama==0.4.6 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.4.6)
# Requirement already satisfied: colorlog==6.7.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (6.7.0)
# Requirement already satisfied: contourpy==1.0.7 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.0.7)
# Requirement already satisfied: cycler==0.11.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.11.0)
# Requirement already satisfied: debugpy==1.5.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.5.1)
# Requirement already satisfied: decorator==5.1.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (5.1.1)
# Requirement already satisfied: deepdiff==6.3.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (6.3.0)
# Requirement already satisfied: defusedxml==0.7.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.7.1)
# Requirement already satisfied: dill==0.3.6 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.3.6)
# Requirement already satisfied: easydev==0.12.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.12.1)
# Requirement already satisfied: entrypoints==0.4 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.4)
# Requirement already satisfied: exceptiongroup==1.1.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.1.1)
# Requirement already satisfied: executing==1.2.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.2.0)
# Requirement already satisfied: fastjsonschema==2.17.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (2.17.1)
# Requirement already satisfied: fonttools==4.39.4 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (4.39.4)
# Requirement already satisfied: fqdn==1.5.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.5.1)
# Requirement already satisfied: greenlet==2.0.2 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (2.0.2)
# Requirement already satisfied: grequests==0.6.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.6.0)
# Requirement already satisfied: idna==3.4 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (3.4)
# Requirement already satisfied: importlib-metadata==6.6.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (6.6.0)
# Requirement already satisfied: importlib-resources==5.12.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (5.12.0)
# Requirement already satisfied: iniconfig==2.0.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (2.0.0)
# Requirement already satisfied: ipykernel==6.15.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (6.15.0)
# Requirement already satisfied: ipython==8.13.2 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (8.13.2)
# Requirement already satisfied: ipython-genutils==0.2.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.2.0)
# Requirement already satisfied: ipywidgets==8.0.6 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (8.0.6)
# Requirement already satisfied: isoduration==20.11.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (20.11.0)
# Requirement already satisfied: jaxtyping==0.2.19 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.2.19)
# Requirement already satisfied: jedi==0.18.2 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.18.2)
# Requirement already satisfied: Jinja2==3.1.2 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (3.1.2)
# Requirement already satisfied: joblib==1.2.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.2.0)
# Requirement already satisfied: jsonpointer==2.3 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (2.3)
# Requirement already satisfied: jsonschema==4.17.3 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (4.17.3)
# Requirement already satisfied: jupyter==1.0.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.0.0)
# Requirement already satisfied: jupyter_client==8.2.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (8.2.0)
# Requirement already satisfied: jupyter-console==6.6.3 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (6.6.3)
# Requirement already satisfied: jupyter_core==5.3.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (5.3.0)
# Requirement already satisfied: jupyter-events==0.6.3 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.6.3)
# Requirement already satisfied: jupyter_server==2.6.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (2.6.0)
# Requirement already satisfied: jupyter_server_terminals==0.4.4 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.4.4)
# Requirement already satisfied: jupyterlab-pygments==0.2.2 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.2.2)
# Requirement already satisfied: jupyterlab-widgets==3.0.7 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (3.0.7)
# Requirement already satisfied: kiwisolver==1.4.4 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.4.4)
# Requirement already satisfied: loguru==0.7.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.7.0)
# Requirement already satisfied: looseversion==1.1.2 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.1.2)
# Requirement already satisfied: lxml==4.9.2 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (4.9.2)
# Requirement already satisfied: markdown-it-py==2.2.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (2.2.0)
# Requirement already satisfied: MarkupSafe==2.1.2 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (2.1.2)
# Requirement already satisfied: matplotlib==3.7.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (3.7.1)
# Requirement already satisfied: matplotlib-inline==0.1.6 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.1.6)
# Requirement already satisfied: mdurl==0.1.2 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.1.2)
# Requirement already satisfied: mistune==2.0.5 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (2.0.5)
# Requirement already satisfied: mmtf-python==1.1.3 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.1.3)
# Requirement already satisfied: msgpack==1.0.5 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.0.5)
# Requirement already satisfied: multipledispatch==0.6.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.6.0)
# Requirement already satisfied: nbclassic==1.0.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.0.0)
# Requirement already satisfied: nbclient==0.8.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.8.0)
# Requirement already satisfied: nbconvert==7.4.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (7.4.0)
# Requirement already satisfied: nbformat==5.8.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (5.8.0)
# Requirement already satisfied: nest-asyncio==1.5.6 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.5.6)
# Requirement already satisfied: networkx==3.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (3.1)
# Requirement already satisfied: notebook==6.5.4 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (6.5.4)
# Requirement already satisfied: notebook_shim==0.2.3 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.2.3)
# Requirement already satisfied: numpy==1.23.5 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.23.5)
# Requirement already satisfied: ordered-set==4.1.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (4.1.0)
# Requirement already satisfied: overrides==7.3.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (7.3.1)
# Requirement already satisfied: packaging==23.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (23.1)
# Requirement already satisfied: pandas==1.5.3 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.5.3)
# Requirement already satisfied: pandocfilters==1.5.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.5.0)
# Requirement already satisfied: parso==0.8.3 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.8.3)
# Requirement already satisfied: pexpect==4.8.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (4.8.0)
# Requirement already satisfied: pickleshare==0.7.5 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.7.5)
# Requirement already satisfied: Pillow==9.5.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (9.5.0)
# Requirement already satisfied: platformdirs==3.5.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (3.5.1)
# Requirement already satisfied: plotly==5.14.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (5.14.1)
# Requirement already satisfied: pluggy==1.0.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.0.0)
# Requirement already satisfied: prometheus-client==0.17.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.17.0)
# Requirement already satisfied: prompt-toolkit==3.0.38 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (3.0.38)
# Requirement already satisfied: psutil==5.9.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (5.9.0)
# Requirement already satisfied: ptyprocess==0.7.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.7.0)
# Requirement already satisfied: pure-eval==0.2.2 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.2.2)
# Requirement already satisfied: pycparser==2.21 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (2.21)
# Requirement already satisfied: pydantic==1.10.8 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.10.8)
# Requirement already satisfied: Pygments==2.15.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (2.15.1)
# Requirement already satisfied: pyparsing==3.0.9 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (3.0.9)
# Requirement already satisfied: pyrsistent==0.19.3 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.19.3)
# Requirement already satisfied: pytest==7.3.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (7.3.1)
# Requirement already satisfied: python-dateutil==2.8.2 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (2.8.2)
# Requirement already satisfied: python-json-logger==2.0.7 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (2.0.7)
# Requirement already satisfied: pytz==2023.3 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (2023.3)
# Requirement already satisfied: pyzmq==25.0.2 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (25.0.2)
# Requirement already satisfied: qtconsole==5.4.3 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (5.4.3)
# Requirement already satisfied: QtPy==2.3.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (2.3.1)
# Requirement already satisfied: requests==2.31.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (2.31.0)
# Requirement already satisfied: requests-cache==1.0.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.0.1)
# Requirement already satisfied: rfc3339-validator==0.1.4 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.1.4)
# Requirement already satisfied: rfc3986-validator==0.1.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.1.1)
# Requirement already satisfied: rich==13.3.5 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (13.3.5)
# Requirement already satisfied: rich-click==1.6.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.6.1)
# Requirement already satisfied: scikit-learn==1.2.2 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.2.2)
# Requirement already satisfied: scipy==1.10.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.10.1)
# Requirement already satisfied: seaborn==0.12.2 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.12.2)
# Requirement already satisfied: Send2Trash==1.8.2 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.8.2)
# Requirement already satisfied: setuptools==66.0.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (66.0.0)
# Requirement already satisfied: six==1.16.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.16.0)
# Requirement already satisfied: sniffio==1.3.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.3.0)
# Requirement already satisfied: soupsieve==2.4.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (2.4.1)
# Requirement already satisfied: stack-data==0.6.2 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.6.2)
# Requirement already satisfied: suds-community==1.1.2 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.1.2)
# Requirement already satisfied: tenacity==8.2.2 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (8.2.2)
# Requirement already satisfied: terminado==0.17.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.17.1)
# Requirement already satisfied: threadpoolctl==3.1.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (3.1.0)
# Requirement already satisfied: tinycss2==1.2.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.2.1)
# Requirement already satisfied: tomli==2.0.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (2.0.1)
# Requirement already satisfied: tornado==6.3.2 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (6.3.2)
# Requirement already satisfied: tqdm==4.65.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (4.65.0)
# Requirement already satisfied: traitlets==5.9.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (5.9.0)
# Requirement already satisfied: typeguard==4.0.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (4.0.0)
# Requirement already satisfied: typing_extensions==4.5.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (4.5.0)
# Requirement already satisfied: tzdata==2023.3 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (2023.3)
# Requirement already satisfied: uri-template==1.2.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.2.0)
# Requirement already satisfied: url-normalize==1.4.3 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.4.3)
# Requirement already satisfied: urllib3==2.0.2 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (2.0.2)
# Requirement already satisfied: wcwidth==0.2.6 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.2.6)
# Requirement already satisfied: webcolors==1.13 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.13)
# Requirement already satisfied: webencodings==0.5.1 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.5.1)
# Requirement already satisfied: websocket-client==1.5.2 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.5.2)
# Requirement already satisfied: wget==3.2 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (3.2)
# Requirement already satisfied: wheel==0.38.4 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.38.4)
# Requirement already satisfied: widgetsnbextension==4.0.7 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (4.0.7)
# Requirement already satisfied: wrapt==1.15.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (1.15.0)
# Requirement already satisfied: xarray==2023.5.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (2023.5.0)
# Requirement already satisfied: xmltodict==0.13.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.13.0)
# Requirement already satisfied: zipp==3.15.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (3.15.0)
# Requirement already satisfied: zope.event==4.6 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (4.6)
# Requirement already satisfied: zope.interface==6.0 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (6.0)
# Requirement already satisfied: colour==0.1.5 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from mutils==0.1) (0.1.5)
# Requirement already satisfied: gevent in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from grequests==0.6.0->mutils==0.1) (23.9.1)
# Requirement already satisfied: pyyaml>=5.3 in /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages (from jupyter-events==0.6.3->mutils==0.1) (6.0.1)
# Building wheels for collected packages: mutils
#   Building wheel for mutils (setup.py) ... done
#   Created wheel for mutils: filename=mutils-0.1-py3-none-any.whl size=177679 sha256=c4ea2fda54f6152398456edc347193b7f6b820962762f3660475c390531929cb
#   Stored in directory: /private/var/folders/yw/q5k8tqgn3tq8_y9lbqhwm_8m0000gn/T/pip-ephem-wheel-cache-btj_axnp/wheels/a5/7d/39/2785c9e54d28c296cac8cceaf579728977e8b7538b9ece023c
# Successfully built mutils
# Installing collected packages: mutils
#   Attempting uninstall: mutils
#     Found existing installation: mutils 0.1
#     Uninstalling mutils-0.1:
#       Successfully uninstalled mutils-0.1
# Successfully installed mutils-0.1

# %%
import copy
from math import sqrt

import esm
import biotite
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.metrics import precision_score, recall_score, roc_auc_score
 
from mutils.data import load_SKEMPI2
from mutils.pdb import get_sequences
from mutils.definitions import MUTILS_SKEMPI2_DIR

tqdm.pandas()

# %%
model, alphabet = esm.pretrained.esm_if1_gvp4_t16_142M_UR50()
model = model.eval()
# Out:
# /Users/anton/dev/esm/esm/pretrained.py:215: UserWarning: Regression weights not found, predicting contacts will not produce correct results.
#   warnings.warn(

# %%
def predict_ddg(esm_model, pdb_path, mutation, chain_ids=None, chain_offsets=None):
    """
    See Appendix B in https://arxiv.org/pdf/2310.18515.pdf
    """
    # Load structure and wild-type sequences
    pdb_path = str(pdb_path)
    if chain_ids is None:
        chain_ids = list(get_sequences(pdb_path).keys())
    structure = esm.inverse_folding.util.load_structure(pdb_path, chain_ids)
    structure = biotite.structure.array([atom for atom in structure if not atom.hetero])
    coords, native_seqs = esm.inverse_folding.multichain_util.extract_coords_from_complex(structure)

    # Create mutant sequences
    mutated_seqs = copy.deepcopy(native_seqs)
    for point_mut in mutation.split(','):
        wt, chain, pos, mut = point_mut[0], point_mut[1], int(point_mut[2:-1]), point_mut[-1]
        pos -= 1  # 0-based indexing
        if chain_offsets is not None and chain in chain_offsets:
            pos -= chain_offsets[chain]
        seq_wt = native_seqs[chain]
        # assert seq_wt[pos] == wt, f'Wild-type sequence does not match the provided mutation: {seq_wt[pos]} != {wt}'
        if seq_wt[pos] != wt:
            print(f'Wild-type sequence does not match the provided mutation {mutation}: {seq_wt[pos]} != {wt}')
        seq_mut = mutated_seqs[chain]
        mutated_seqs[chain] = seq_mut[:pos] + mut + seq_mut[pos+1:]

    # Calculate average log likelihood for wild-type and mutant complexes
    ll_wt, ll_mut = [], []
    for chain in native_seqs.keys():
        seq_wt = native_seqs[chain]
        seq_mut = mutated_seqs[chain]
        if seq_wt != seq_mut:
            ll_wt_chain, _ = esm.inverse_folding.multichain_util.score_sequence_in_complex(
                esm_model, alphabet, coords, chain, seq_wt)
            ll_mut_chain, _ = esm.inverse_folding.multichain_util.score_sequence_in_complex(
                esm_model, alphabet, coords, chain, seq_mut)
            ll_wt.append(ll_wt_chain)
            ll_mut.append(ll_mut_chain)
    ll_wt = np.mean(ll_wt)
    ll_wt = ll_wt.round(2)
    ll_mut = np.mean(ll_mut)

    # Calculate predicted ddG
    ddg_pred = ll_wt - ll_mut
    return ddg_pred
    

# To have SKEMPI2 .pdb files in `MUTILS_SKEMPI2_DIR / 'PDBs'` directory,
# clone mutils from github (https://github.com/anton-bushuiev/mutils) and install in editable mode (pip install -e mutils).
# Alternatively, download the files from https://life.bsc.es/pid/skempi2/database/index
# predict_ddg(model, MUTILS_SKEMPI2_DIR / 'PDBs' / '1C4Z.pdb', 'ED90R')
# predict_ddg(model, MUTILS_SKEMPI2_DIR / 'PDBs' / '1KNE.pdb', 'TP2K')
# predict_ddg(model, MUTILS_SKEMPI2_DIR / 'PDBs' / '1KNE.pdb', 'DA40T,TP2L')
predict_ddg(model, MUTILS_SKEMPI2_DIR / 'PDBs' / '2NOJ.pdb', 'RB24A,NB31A')
# Out:
# /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'TER' at line 2008
#   warnings.warn(
# /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages/Bio/PDB/PDBParser.py:395: PDBConstructionWarning: Ignoring unrecognized record 'TER' at line 2463
#   warnings.warn(
# /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain A is discontinuous at line 2464.
#   warnings.warn(
# /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages/Bio/PDB/StructureBuilder.py:89: PDBConstructionWarning: WARNING: Chain B is discontinuous at line 2476.
#   warnings.warn(
# 0.17954417787749177

# %% [markdown]
# # SKEMPI v2.0 test set

# %%
# Read ids for test complexes
df_ppiformer = pd.read_csv('https://raw.githubusercontent.com/anton-bushuiev/mutils/main/mutils/datasets/SKEMPI2/predictions_test/ppiformer.csv')
test_complexes = df_ppiformer['complex'].unique()
test_complexes
# Out:
# array(['1KNE_A_P', '1C4Z_ABC_D', '5CXB_A_B', '5CYK_A_B', '1BRS_A_D',
#        '1B2U_A_D', '1B2S_A_D', '1B3S_A_D', '1X1W_A_D', '1X1X_A_D',
#        '2GOX_A_B', '3D5S_A_C', '3D5R_A_C', '2NOJ_A_B'], dtype=object)

# %%
# Read dataframe for SKEMPI2 test set
from mutils.data import load_SKEMPI2
df_s2 = load_SKEMPI2()[0]
df_s2_test = df_s2[df_s2['#Pdb'].isin(test_complexes)]
df_s2_test
# Out:
#           #Pdb Mutation(s)_PDB Mutation(s)_cleaned iMutation_Location(s)  \
# 104   1BRS_A_D           KA27A               KA25A                   COR
# 105   1BRS_A_D           RA59A               RA57A                   COR
# 106   1BRS_A_D           RA83Q               RA81Q                   COR
# 107   1BRS_A_D           RA87A               RA85A                   SUP
# 108   1BRS_A_D          HA102A              HA100A                   COR
# ...        ...             ...                 ...                   ...
# 6241  5CYK_A_B          EB486R               EB52R                   COR
# 6242  5CYK_A_B   EB486R,EB481D         EB52R,EB47D               COR,COR
# 6243  5CYK_A_B   EB486R,TB484Q         EB52R,TB50Q               COR,COR
# 6244  5CYK_A_B          EB486A               EB52A                   COR
# 6245  5CYK_A_B   EB486R,VB488W         EB52R,VB54W               COR,COR
#
#      Hold_out_type                                  Hold_out_proteins  \
# 104          Other  1BRS_A_D,1B2U_A_D,1B2S_A_D,1B3S_A_D,1X1W_A_D,1...
# 105          Other  1BRS_A_D,1B2U_A_D,1B2S_A_D,1B3S_A_D,1X1W_A_D,1...
# 106          Other  1BRS_A_D,1B2U_A_D,1B2S_A_D,1B3S_A_D,1X1W_A_D,1...
# 107          Other  1BRS_A_D,1B2U_A_D,1B2S_A_D,1B3S_A_D,1X1W_A_D,1...
# 108          Other  1BRS_A_D,1B2U_A_D,1B2S_A_D,1B3S_A_D,1X1W_A_D,1...
# ...            ...                                                ...
# 6241         Other                                  5CXB_A_B,5CYK_A_B
# 6242         Other                                  5CXB_A_B,5CYK_A_B
# 6243         Other                                  5CXB_A_B,5CYK_A_B
# 6244         Other                                  5CXB_A_B,5CYK_A_B
# 6245         Other                                  5CXB_A_B,5CYK_A_B
#
#       Affinity_mut (M)  Affinity_mut_parsed  Affinity_wt (M)  \
# 104       8.800000e-11         8.800000e-11     1.000000e-14
# 105       7.000000e-11         7.000000e-11     1.000000e-14
# 106       9.400000e-11         9.400000e-11     1.000000e-14
# 107       1.200000e-10         1.200000e-10     1.000000e-14
# 108       3.200000e-10         3.200000e-10     1.000000e-14
# ...                ...                  ...              ...
# 6241      2.700000e-09         2.700000e-09     2.490000e-07
# 6242      5.000000e-09         5.000000e-09     2.490000e-07
# 6243      3.000000e-09         3.000000e-09     2.490000e-07
# 6244      7.000000e-09         7.000000e-09     2.490000e-07
# 6245      7.000000e-09         7.000000e-09     2.490000e-07
#
#       Affinity_wt_parsed  ... dS_wt (cal mol^(-1) K^(-1))  \
# 104         1.000000e-14  ...                       -1.01
# 105         1.000000e-14  ...                       -1.01
# 106         1.000000e-14  ...                         NaN
# 107         1.000000e-14  ...                       -1.01
# 108         1.000000e-14  ...                       -1.01
# ...                  ...  ...                         ...
# 6241        2.490000e-07  ...                         NaN
# 6242        2.490000e-07  ...                         NaN
# 6243        2.490000e-07  ...                         NaN
# 6244        2.490000e-07  ...                         NaN
# 6245        2.490000e-07  ...                         NaN
#
#                                                   Notes Method SKEMPI version  \
# 104                  Thermodynamic data from 9126847.,,    ITC              1
# 105                  Thermodynamic data from 9126847.,,    ITC              1
# 106                                                 NaN   SFFL              1
# 107                  Thermodynamic data from 9126847.,,    ITC              1
# 108                  Thermodynamic data from 9126847.,,    ITC              1
# ...                                                 ...    ...            ...
# 6241  Crystal structure is one of the mutants in the...     BI              2
# 6242  Crystal structure is one of the mutants in the...     BI              2
# 6243  Crystal structure is one of the mutants in the...     BI              2
# 6244  Crystal structure is one of the mutants in the...     BI              2
# 6245  Crystal structure is one of the mutants in the...     BI              2
#
#          dG_mut      dG_wt       ddG  PDB Id Partner 1  Partner 2
# 104  -13.717446 -19.098395  5.380949    1BRS         A          D
# 105  -13.853024 -19.098395  5.245372    1BRS         A          D
# 106  -13.678369 -19.098395  5.420026    1BRS         A          D
# 107  -13.533694 -19.098395  5.564701    1BRS         A          D
# 108  -12.952600 -19.098395  6.145795    1BRS         A          D
# ...         ...        ...       ...     ...       ...        ...
# 6241 -11.689086  -9.008714 -2.680372    5CYK         A          B
# 6242 -11.324025  -9.008714 -2.315311    5CYK         A          B
# 6243 -11.626665  -9.008714 -2.617951    5CYK         A          B
# 6244 -11.124682  -9.008714 -2.115968    5CYK         A          B
# 6245 -11.124682  -9.008714 -2.115968    5CYK         A          B
#
# [219 rows x 35 columns]

# %%
# To have SKEMPI2 .pdb files in `MUTILS_SKEMPI2_DIR / 'PDBs'` directory,
# clone mutils from github (https://github.com/anton-bushuiev/mutils) and install in editable mode (pip install -e mutils).
# Alternatively, download the files from https://life.bsc.es/pid/skempi2/database/index
df_s2_test['ddG_pred'] = df_s2_test.progress_apply(
    lambda row: predict_ddg(
        esm_model=model,
        pdb_path=MUTILS_SKEMPI2_DIR / 'PDBs' / f'{row["PDB Id"]}.pdb',
        mutation=row['Mutation(s)_cleaned'],
        chain_ids=list(''.join(row['#Pdb'].split('_')[1:]))
    ),
    axis=1
)
# Out:
# 100%|██████████| 219/219 [33:09<00:00,  9.08s/it]
# /var/folders/yw/q5k8tqgn3tq8_y9lbqhwm_8m0000gn/T/ipykernel_20749/4068229225.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_s2_test['ddG_pred'] = df_s2_test.progress_apply(

# %%
def metrics_from_df(df):
    pred = df['ddG_pred'] < 0
    real = df['ddG'] < 0
    return {
        'Spearman': df['ddG'].corr(df['ddG_pred'], method='spearman'),
        'Pearson': df['ddG'].corr(df['ddG_pred'], method='pearson'),
        'Precision': precision_score(real, pred),
        'Recall': recall_score(real, pred),
        'ROC AUC': roc_auc_score(real, -df['ddG_pred']) if len(df) else np.nan,
        'MAE': (df['ddG'] - df['ddG_pred']).abs().mean(),
        'RMSE': sqrt((df['ddG'] - df['ddG_pred']).pow(2).mean())
    }


res = df_s2_test.groupby('Protein 1').apply(metrics_from_df)
df_s2_test_agg = pd.DataFrame(res.tolist())
df_s2_test_agg = df_s2_test_agg.set_index(res.index)
display(df_s2_test_agg[['Spearman', 'Precision', 'Recall']])

df_s2_test_agg.mean()
# Out:
# /Users/anton/miniconda3/envs/ppiformer_u/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                       Spearman  Precision    Recall
# Protein 1
# Barnase               0.176488   0.411765  0.500000
# C. thermophilum YTM1  0.085367   0.000000  0.000000
# Complement C3d        0.339032   0.500000  0.500000
# E6AP                  0.213210   0.307692  0.333333
# dHP1 Chromodomain     0.104578   0.454545  0.714286
# Spearman     0.183735
# Pearson      0.175749
# Precision    0.334800
# Recall       0.409524
# ROC AUC      0.680099
# MAE          1.868550
# RMSE         2.151956
# dtype: float64

# %% [markdown]
# # SAK (staphylokinase) test set

# %%
df_sak = pd.read_csv('./ppiformer_test_data/sak.csv')
df_sak
# Out:
#           #Pdb                      Mutation(s)  Activity  \
# 0   1BUI_A_B_C                      EC38A,EC75A        66
# 1   1BUI_A_B_C                            KC74A       100
# 2   1BUI_A_B_C                            EC75A       140
# 3   1BUI_A_B_C                            SC16A       160
# 4   1BUI_A_B_C                      YC17A,FC18A        30
# ..         ...                              ...       ...
# 75  1BUI_A_B_C  GC36R,HC43R,KC74R,KC130T,KC135R       160
# 76  1BUI_A_B_C        KC74Q,KC86A,KC130T,KC135R       130
# 77  1BUI_A_B_C              KC74Q,KC130A,KC135R       240
# 78  1BUI_A_B_C              KC74Q,KC130E,KC135R       300
# 79  1BUI_A_B_C                           KC102C       143
#
#     Activity enhancement  2x activity enhancement
# 0                  False                    False
# 1                  False                    False
# 2                   True                    False
# 3                   True                    False
# 4                  False                    False
# ..                   ...                      ...
# 75                  True                    False
# 76                 False                    False
# 77                  True                    False
# 78                  True                     True
# 79                  True                    False
#
# [80 rows x 5 columns]

# %%
df_sak['ddG_pred'] = df_sak.progress_apply(
    lambda row: predict_ddg(
        esm_model=model,
        pdb_path='./ppiformer_test_data/1BUI_A_B_C.pdb',
        mutation=row['Mutation(s)'],
        chain_ids=['A', 'B', 'C'],
        chain_offsets={'C': 14}  # C starts with 15 in 1bui
    ),
    axis=1
)
# Out:
# 100%|██████████| 80/80 [15:02<00:00, 11.28s/it]

# %%
df_sak['rank'] = df_sak['ddG_pred'].rank() / len(df_sak)
df_sak[df_sak['2x activity enhancement']][['Mutation(s)', 'rank']]
# Out:
#             Mutation(s)    rank
# 42               KC130A  0.4500
# 44               KC135A  0.2500
# 65               KC130T  0.3375
# 69        KC130T,KC135R  0.4625
# 71  KC74R,KC130T,KC135R  0.5875
# 78  KC74Q,KC130E,KC135R  0.4250

# %% [markdown]
# # COVID benchmark from (Shan 2022)

# %%
df_cov = pd.read_csv('./ppiformer_test_data/shan2022_sars-cov-2.csv')
df_cov
# Out:
#                   #Pdb Mutation(s)  Stabilizing
# 0    7FAE-RBD-Fv_A_H_L       AH53C        False
# 1    7FAE-RBD-Fv_A_H_L       AH53D        False
# 2    7FAE-RBD-Fv_A_H_L       AH53E        False
# 3    7FAE-RBD-Fv_A_H_L       AH53F         True
# 4    7FAE-RBD-Fv_A_H_L       AH53G        False
# ..                 ...         ...          ...
# 489  7FAE-RBD-Fv_A_H_L       YH32R        False
# 490  7FAE-RBD-Fv_A_H_L       YH32S        False
# 491  7FAE-RBD-Fv_A_H_L       YH32T        False
# 492  7FAE-RBD-Fv_A_H_L       YH32V        False
# 493  7FAE-RBD-Fv_A_H_L       YH32W        False
#
# [494 rows x 3 columns]

# %%
df_cov['ddG_pred'] = df_cov.progress_apply(
    lambda row: predict_ddg(
        esm_model=model,
        pdb_path='./ppiformer_test_data/7FAE_RBD_Fv.pdb',
        mutation=row['Mutation(s)'],
        chain_ids=['A', 'H', 'L']
    ),
    axis=1
)
# Out:
# 100%|██████████| 494/494 [50:26<00:00,  6.13s/it]

# %%
df_cov['rank'] = df_cov['ddG_pred'].rank() / len(df_cov)
df_cov[df_cov['Stabilizing']][['Mutation(s)', 'rank']]
# Out:
#     Mutation(s)      rank
# 3         AH53F  0.176113
# 232      LH104F  0.485830
# 294       NH57L  0.170040
# 352      RH103M  0.514170
# 416       TH31W  0.493927
